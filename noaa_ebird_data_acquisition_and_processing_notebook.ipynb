# %%
# !pip install noaa_coops
# Out:
# Requirement already satisfied: noaa_coops in /usr/local/lib/python3.7/dist-packages (0.1.9)
# Requirement already satisfied: zeep in /usr/local/lib/python3.7/dist-packages (from noaa_coops) (4.0.0)
# Requirement already satisfied: pandas>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from noaa_coops) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from noaa_coops) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from noaa_coops) (1.19.5)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (4.2.6)
# Requirement already satisfied: defusedxml>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (0.7.0)
# Requirement already satisfied: requests-file>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (1.5.1)
# Requirement already satisfied: cached-property>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (1.5.2)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (0.9.1)
# Requirement already satisfied: isodate>=0.5.4 in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (0.6.0)
# Requirement already satisfied: appdirs>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (1.4.4)
# Requirement already satisfied: attrs>=17.2.0 in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (20.3.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from zeep->noaa_coops) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.3->noaa_coops) (2.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->noaa_coops) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->noaa_coops) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->noaa_coops) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->noaa_coops) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from requests-file>=1.5.1->zeep->noaa_coops) (1.15.0)

# %% [markdown]
# The tidal data will be retrieved from the National Oceanic and Atmospheric Admistration Center for Operational Oceanographic Products and Services (NOAA CO-OPS) API. This API allows querying by tidal observation station ID. For the purpose of this project, the tidal observation stations in Atlantic City, Ship John Shoal, Cape May, and Sandy Hook will be used. Data is retrieved using the 'get_data' function and is returned in the pandas dataframe format. The pandas dataframes are converted into namedtuples below to allow flexible manipulation. Attributes of the dataset include high tide time, high tide water level, low tide time, low tide water level, and date.

# %%
# get tidal data from noaa coops api
import noaa_coops as nc # noaa_coops api
from datetime import date, timedelta, datetime
atlantic_city = nc.Station(8534720)
cape_may = nc.Station(8536110)
sandy_hook = nc.Station(8531680)
ship_john_shoal = nc.Station(8537121)

today = date.today().strftime('%Y-%m-%d')
today = str(today.replace('-', ''))

end_date = datetime.today() - timedelta(days=0)
end_date = end_date.strftime('%Y-%m-%d')
end_date = str(end_date.replace('-', ''))

start_date = '20200101'

atlantic_city_tides = atlantic_city.get_data(
     begin_date= start_date,
     end_date= end_date,
     product="high_low",
     datum="STND",
     units="metric",
     time_zone="gmt")

ship_john_shoal_tides = ship_john_shoal.get_data(
     begin_date= start_date,
     end_date= end_date,
     product="high_low",
     datum="STND",
     units="metric",
     time_zone="gmt")

cape_may_tides = cape_may.get_data(
     begin_date=start_date,
     end_date=end_date,
     product="high_low",
     datum="STND",
     units="metric",
     time_zone="gmt")

sandy_hook_tides = sandy_hook.get_data(
     begin_date=start_date,
     end_date=end_date,
     product="high_low",
     datum="STND",
     units="metric",
     time_zone="gmt")

# %%
ac_tides = list(atlantic_city_tides.itertuples(index=False, name='Atlantic_City'))
sjs_tides = list(ship_john_shoal_tides.itertuples(index=False, name='Cumberland_County'))
cm_tides = list(cape_may_tides.itertuples(index=False, name='Cape_May'))
sh_tides = list(sandy_hook_tides.itertuples(index=False, name='Sandy_Hook'))

tides_all = {'Cumberland': sjs_tides, 'Cape May': cm_tides, 'Monmouth': sh_tides, 'Atlantic': ac_tides}

for key, value in tides_all.items():
  current_list = value
  for i in range(len(current_list)):
    print(current_list[i])
# Out:
# Cumberland_County(date_time_HH=Timestamp('2020-01-01 19:12:00'), HH_water_level=7.376, date_time_H=Timestamp('2020-01-01 06:42:00'), H_water_level=7.325, date_time_L=Timestamp('2020-01-01 01:12:00'), L_water_level=6.12, date_time_LL=Timestamp('2020-01-01 13:06:00'), LL_water_level=5.8420000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-01-02 19:54:00'), HH_water_level=7.3229999999999995, date_time_H=Timestamp('2020-01-02 07:42:00'), H_water_level=7.228, date_time_L=Timestamp('2020-01-02 14:00:00'), L_water_level=5.886, date_time_LL=Timestamp('2020-01-02 01:48:00'), LL_water_level=5.803999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-01-03 20:48:00'), HH_water_level=7.294, date_time_H=Timestamp('2020-01-03 08:36:00'), H_water_level=7.254, date_time_L=Timestamp('2020-01-03 14:42:00'), L_water_level=5.978, date_time_LL=Timestamp('2020-01-03 02:36:00'), LL_water_level=5.775)
# Cumberland_County(date_time_HH=Timestamp('2020-01-04 09:24:00'), HH_water_level=7.496, date_time_H=Timestamp('2020-01-04 21:24:00'), H_water_level=7.394, date_time_L=Timestamp('2020-01-04 15:42:00'), L_water_level=6.257999999999999, date_time_LL=Timestamp('2020-01-04 03:12:00'), LL_water_level=5.917000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-01-05 10:18:00'), HH_water_level=7.015, date_time_H=Timestamp('2020-01-05 22:48:00'), H_water_level=6.914, date_time_L=Timestamp('2020-01-05 04:12:00'), L_water_level=5.851, date_time_LL=Timestamp('2020-01-05 17:00:00'), LL_water_level=5.625)
# Cumberland_County(date_time_HH=Timestamp('2020-01-06 11:06:00'), HH_water_level=7.473, date_time_H=Timestamp('2020-01-06 23:42:00'), H_water_level=7.287000000000001, date_time_L=Timestamp('2020-01-06 17:54:00'), L_water_level=5.904, date_time_LL=Timestamp('2020-01-06 04:48:00'), LL_water_level=5.71)
# Cumberland_County(date_time_HH=Timestamp('2020-01-07 12:00:00'), HH_water_level=7.526, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-01-07 18:42:00'), L_water_level=5.876, date_time_LL=Timestamp('2020-01-07 05:54:00'), LL_water_level=5.702999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-01-08 12:54:00'), HH_water_level=7.622000000000001, date_time_H=Timestamp('2020-01-08 00:24:00'), H_water_level=7.456, date_time_L=Timestamp('2020-01-08 06:36:00'), L_water_level=5.651, date_time_LL=Timestamp('2020-01-08 20:54:00'), LL_water_level=5.417999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-01-09 14:06:00'), HH_water_level=7.189, date_time_H=Timestamp('2020-01-09 01:18:00'), H_water_level=6.7139999999999995, date_time_L=Timestamp('2020-01-09 20:36:00'), L_water_level=5.386, date_time_LL=Timestamp('2020-01-09 07:42:00'), LL_water_level=5.244)
# Cumberland_County(date_time_HH=Timestamp('2020-01-10 14:42:00'), HH_water_level=7.602, date_time_H=Timestamp('2020-01-10 02:06:00'), H_water_level=7.112, date_time_L=Timestamp('2020-01-10 21:24:00'), L_water_level=5.542999999999999, date_time_LL=Timestamp('2020-01-10 08:24:00'), LL_water_level=5.481)
# Cumberland_County(date_time_HH=Timestamp('2020-01-11 15:24:00'), HH_water_level=7.6770000000000005, date_time_H=Timestamp('2020-01-11 02:54:00'), H_water_level=7.183, date_time_L=Timestamp('2020-01-11 22:12:00'), L_water_level=5.624, date_time_LL=Timestamp('2020-01-11 09:18:00'), LL_water_level=5.445)
# Cumberland_County(date_time_HH=Timestamp('2020-01-12 16:00:00'), HH_water_level=7.439, date_time_H=Timestamp('2020-01-12 03:24:00'), H_water_level=7.266, date_time_L=Timestamp('2020-01-12 10:06:00'), L_water_level=5.539, date_time_LL=Timestamp('2020-01-12 23:00:00'), LL_water_level=5.265)
# Cumberland_County(date_time_HH=Timestamp('2020-01-13 16:42:00'), HH_water_level=7.694, date_time_H=Timestamp('2020-01-13 04:42:00'), H_water_level=7.14, date_time_L=Timestamp('2020-01-13 23:42:00'), L_water_level=5.5729999999999995, date_time_LL=Timestamp('2020-01-13 10:42:00'), LL_water_level=5.436)
# Cumberland_County(date_time_HH=Timestamp('2020-01-14 17:30:00'), HH_water_level=7.763, date_time_H=Timestamp('2020-01-14 05:18:00'), H_water_level=7.515, date_time_L=Timestamp('2020-01-14 11:42:00'), L_water_level=5.742999999999999, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-01-15 18:24:00'), HH_water_level=7.632999999999999, date_time_H=Timestamp('2020-01-15 06:06:00'), H_water_level=7.495, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-01-15 00:24:00'), LL_water_level=5.699)
# Cumberland_County(date_time_HH=Timestamp('2020-01-16 19:06:00'), HH_water_level=7.194, date_time_H=Timestamp('2020-01-16 07:06:00'), H_water_level=7.571000000000001, date_time_L=Timestamp('2020-01-16 01:18:00'), L_water_level=5.776, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-01-17 20:48:00'), H_water_level=7.142, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-01-17 02:36:00'), LL_water_level=5.257000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-01-18 09:18:00'), HH_water_level=7.662999999999999, date_time_H=Timestamp('2020-01-18 21:36:00'), H_water_level=7.562, date_time_L=Timestamp('2020-01-18 15:42:00'), L_water_level=5.952000000000001, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-01-19 10:12:00'), HH_water_level=7.585, date_time_H=Timestamp('2020-01-19 22:30:00'), H_water_level=6.9510000000000005, date_time_L=Timestamp('2020-01-19 17:18:00'), L_water_level=5.631, date_time_LL=Timestamp('2020-01-19 04:06:00'), LL_water_level=5.932)
# Cumberland_County(date_time_HH=Timestamp('2020-01-20 11:24:00'), HH_water_level=7.244, date_time_H=Timestamp('2020-01-20 23:36:00'), H_water_level=7.244, date_time_L=Timestamp('2020-01-20 17:54:00'), L_water_level=5.768, date_time_LL=Timestamp('2020-01-20 05:18:00'), LL_water_level=5.445)
# Cumberland_County(date_time_HH=Timestamp('2020-01-21 12:24:00'), HH_water_level=7.597, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-01-21 19:00:00'), L_water_level=5.818, date_time_LL=Timestamp('2020-01-21 06:06:00'), LL_water_level=5.5760000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-01-22 13:00:00'), HH_water_level=7.67, date_time_H=Timestamp('2020-01-22 00:36:00'), H_water_level=7.3660000000000005, date_time_L=Timestamp('2020-01-22 19:54:00'), L_water_level=5.681, date_time_LL=Timestamp('2020-01-22 06:54:00'), LL_water_level=5.712999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-01-23 13:48:00'), HH_water_level=7.596, date_time_H=Timestamp('2020-01-23 01:24:00'), H_water_level=7.341, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-01-23 07:48:00'), LL_water_level=5.667000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-01-24 14:42:00'), HH_water_level=7.66, date_time_H=Timestamp('2020-01-24 02:12:00'), H_water_level=7.3020000000000005, date_time_L=Timestamp('2020-01-24 08:36:00'), L_water_level=5.662000000000001, date_time_LL=Timestamp('2020-01-24 21:30:00'), LL_water_level=5.7860000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-01-25 15:18:00'), HH_water_level=8.089, date_time_H=Timestamp('2020-01-25 03:00:00'), H_water_level=7.377999999999999, date_time_L=Timestamp('2020-01-25 22:18:00'), L_water_level=6.018, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-01-26 16:00:00'), HH_water_level=7.782, date_time_H=Timestamp('2020-01-26 03:36:00'), H_water_level=7.522, date_time_L=Timestamp('2020-01-26 23:00:00'), L_water_level=5.79, date_time_LL=Timestamp('2020-01-26 10:06:00'), LL_water_level=5.87)
# Cumberland_County(date_time_HH=Timestamp('2020-01-27 16:36:00'), HH_water_level=7.579, date_time_H=Timestamp('2020-01-27 04:18:00'), H_water_level=7.3020000000000005, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-01-27 10:36:00'), LL_water_level=5.676)
# Cumberland_County(date_time_HH=Timestamp('2020-01-28 17:06:00'), HH_water_level=7.405, date_time_H=Timestamp('2020-01-28 05:00:00'), H_water_level=7.324, date_time_L=Timestamp('2020-01-28 11:18:00'), L_water_level=5.686, date_time_LL=Timestamp('2020-01-28 23:36:00'), LL_water_level=5.742000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-01-29 17:54:00'), HH_water_level=7.457000000000001, date_time_H=Timestamp('2020-01-29 05:36:00'), H_water_level=7.405, date_time_L=Timestamp('2020-01-29 11:42:00'), L_water_level=5.877000000000001, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-01-30 18:18:00'), HH_water_level=7.525, date_time_H=Timestamp('2020-01-30 06:12:00'), H_water_level=7.436, date_time_L=Timestamp('2020-01-30 12:24:00'), L_water_level=6.013, date_time_LL=Timestamp('2020-01-30 00:06:00'), LL_water_level=5.89)
# Cumberland_County(date_time_HH=Timestamp('2020-01-31 06:54:00'), HH_water_level=7.428999999999999, date_time_H=Timestamp('2020-01-31 19:06:00'), H_water_level=7.361000000000001, date_time_L=Timestamp('2020-01-31 13:06:00'), L_water_level=6.001, date_time_LL=Timestamp('2020-01-31 00:48:00'), LL_water_level=5.946000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-02-01 07:36:00'), HH_water_level=7.439, date_time_H=Timestamp('2020-02-01 19:54:00'), H_water_level=7.361000000000001, date_time_L=Timestamp('2020-02-01 13:54:00'), L_water_level=6.057, date_time_LL=Timestamp('2020-02-01 01:30:00'), LL_water_level=5.933)
# Cumberland_County(date_time_HH=Timestamp('2020-02-02 08:18:00'), HH_water_level=7.49, date_time_H=Timestamp('2020-02-02 20:42:00'), H_water_level=7.33, date_time_L=Timestamp('2020-02-02 14:54:00'), L_water_level=6.106, date_time_LL=Timestamp('2020-02-02 02:18:00'), LL_water_level=6.024)
# Cumberland_County(date_time_HH=Timestamp('2020-02-03 09:12:00'), HH_water_level=7.499, date_time_H=Timestamp('2020-02-03 21:36:00'), H_water_level=7.197, date_time_L=Timestamp('2020-02-03 03:24:00'), L_water_level=6.138, date_time_LL=Timestamp('2020-02-03 15:54:00'), LL_water_level=5.99)
# Cumberland_County(date_time_HH=Timestamp('2020-02-04 10:24:00'), HH_water_level=7.5520000000000005, date_time_H=Timestamp('2020-02-04 22:48:00'), H_water_level=7.22, date_time_L=Timestamp('2020-02-04 17:06:00'), L_water_level=5.9670000000000005, date_time_LL=Timestamp('2020-02-04 04:00:00'), LL_water_level=5.917999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-02-05 11:12:00'), HH_water_level=7.567, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-02-05 18:00:00'), L_water_level=6.018, date_time_LL=Timestamp('2020-02-05 05:12:00'), LL_water_level=5.796)
# Cumberland_County(date_time_HH=Timestamp('2020-02-06 12:06:00'), HH_water_level=7.766, date_time_H=Timestamp('2020-02-06 00:00:00'), H_water_level=7.422000000000001, date_time_L=Timestamp('2020-02-06 06:00:00'), L_water_level=6.026, date_time_LL=Timestamp('2020-02-06 19:06:00'), LL_water_level=5.985)
# Cumberland_County(date_time_HH=Timestamp('2020-02-07 13:18:00'), HH_water_level=8.054, date_time_H=Timestamp('2020-02-07 00:48:00'), H_water_level=7.582000000000001, date_time_L=Timestamp('2020-02-07 07:00:00'), L_water_level=6.002000000000001, date_time_LL=Timestamp('2020-02-07 21:36:00'), LL_water_level=5.546)
# Cumberland_County(date_time_HH=Timestamp('2020-02-08 14:24:00'), HH_water_level=7.281000000000001, date_time_H=Timestamp('2020-02-08 01:18:00'), H_water_level=6.767, date_time_L=Timestamp('2020-02-08 21:24:00'), L_water_level=5.185, date_time_LL=Timestamp('2020-02-08 08:24:00'), LL_water_level=5.1)
# Cumberland_County(date_time_HH=Timestamp('2020-02-09 15:00:00'), HH_water_level=7.59, date_time_H=Timestamp('2020-02-09 02:48:00'), H_water_level=7.037000000000001, date_time_L=Timestamp('2020-02-09 21:48:00'), L_water_level=5.48, date_time_LL=Timestamp('2020-02-09 09:06:00'), LL_water_level=5.26)
# Cumberland_County(date_time_HH=Timestamp('2020-02-10 15:48:00'), HH_water_level=7.727, date_time_H=Timestamp('2020-02-10 03:18:00'), H_water_level=7.465, date_time_L=Timestamp('2020-02-10 09:54:00'), L_water_level=5.52, date_time_LL=Timestamp('2020-02-10 23:00:00'), LL_water_level=5.441)
# Cumberland_County(date_time_HH=Timestamp('2020-02-11 16:36:00'), HH_water_level=7.726, date_time_H=Timestamp('2020-02-11 04:12:00'), H_water_level=7.4079999999999995, date_time_L=Timestamp('2020-02-11 23:24:00'), L_water_level=5.544, date_time_LL=Timestamp('2020-02-11 10:42:00'), LL_water_level=5.4910000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-02-12 17:30:00'), HH_water_level=7.649, date_time_H=Timestamp('2020-02-12 05:06:00'), H_water_level=7.586, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-02-12 11:42:00'), LL_water_level=5.516)
# Cumberland_County(date_time_HH=Timestamp('2020-02-13 18:18:00'), HH_water_level=7.662000000000001, date_time_H=Timestamp('2020-02-13 06:00:00'), H_water_level=7.591, date_time_L=Timestamp('2020-02-13 12:36:00'), L_water_level=5.683, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-02-14 06:42:00'), H_water_level=7.343999999999999, date_time_L=Timestamp('2020-02-14 13:48:00'), L_water_level=5.496, date_time_LL=Timestamp('2020-02-14 01:06:00'), LL_water_level=5.672999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-02-15 07:54:00'), HH_water_level=7.443, date_time_H=Timestamp('2020-02-15 20:12:00'), H_water_level=7.311, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-02-15 14:30:00'), LL_water_level=5.737)
# Cumberland_County(date_time_HH=Timestamp('2020-02-16 08:42:00'), HH_water_level=7.481, date_time_H=Timestamp('2020-02-16 21:12:00'), H_water_level=7.072, date_time_L=Timestamp('2020-02-16 02:36:00'), L_water_level=5.746, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-02-17 09:54:00'), HH_water_level=7.405, date_time_H=Timestamp('2020-02-17 22:18:00'), H_water_level=7.193, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-02-17 16:24:00'), LL_water_level=5.702999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-02-18 11:00:00'), HH_water_level=7.617000000000001, date_time_H=Timestamp('2020-02-18 23:30:00'), H_water_level=7.379, date_time_L=Timestamp('2020-02-18 17:36:00'), L_water_level=5.979, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-02-19 11:30:00'), HH_water_level=7.513999999999999, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-02-19 18:48:00'), L_water_level=5.624, date_time_LL=Timestamp('2020-02-19 05:42:00'), LL_water_level=5.864)
# Cumberland_County(date_time_HH=Timestamp('2020-02-20 13:00:00'), HH_water_level=7.311, date_time_H=Timestamp('2020-02-20 00:30:00'), H_water_level=7.064, date_time_L=Timestamp('2020-02-20 19:48:00'), L_water_level=5.562, date_time_LL=Timestamp('2020-02-20 06:48:00'), LL_water_level=5.497000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-02-21 13:54:00'), HH_water_level=7.331, date_time_H=Timestamp('2020-02-21 01:18:00'), H_water_level=7.05, date_time_L=Timestamp('2020-02-21 20:54:00'), L_water_level=5.632000000000001, date_time_LL=Timestamp('2020-02-21 07:36:00'), LL_water_level=5.492999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-02-22 14:18:00'), HH_water_level=7.4670000000000005, date_time_H=Timestamp('2020-02-22 02:12:00'), H_water_level=7.204, date_time_L=Timestamp('2020-02-22 21:18:00'), L_water_level=5.519, date_time_LL=Timestamp('2020-02-22 08:18:00'), LL_water_level=5.6)
# Cumberland_County(date_time_HH=Timestamp('2020-02-23 15:18:00'), HH_water_level=7.372000000000001, date_time_H=Timestamp('2020-02-23 02:36:00'), H_water_level=7.148, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-02-23 21:42:00'), LL_water_level=5.622999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-02-24 15:42:00'), HH_water_level=7.551, date_time_H=Timestamp('2020-02-24 03:12:00'), H_water_level=7.371, date_time_L=Timestamp('2020-02-24 22:12:00'), L_water_level=5.797000000000001, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-02-25 16:12:00'), HH_water_level=7.64, date_time_H=Timestamp('2020-02-25 03:42:00'), H_water_level=7.415, date_time_L=Timestamp('2020-02-25 22:48:00'), L_water_level=5.846, date_time_LL=Timestamp('2020-02-25 10:06:00'), LL_water_level=5.782)
# Cumberland_County(date_time_HH=Timestamp('2020-02-26 16:48:00'), HH_water_level=7.635, date_time_H=Timestamp('2020-02-26 04:24:00'), H_water_level=7.483, date_time_L=Timestamp('2020-02-26 23:00:00'), L_water_level=5.952000000000001, date_time_LL=Timestamp('2020-02-26 10:42:00'), LL_water_level=5.8260000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-02-27 05:12:00'), HH_water_level=7.699, date_time_H=Timestamp('2020-02-27 17:00:00'), H_water_level=7.047999999999999, date_time_L=Timestamp('2020-02-27 23:54:00'), L_water_level=5.432, date_time_LL=Timestamp('2020-02-27 12:54:00'), LL_water_level=5.808)
# Cumberland_County(date_time_HH=Timestamp('2020-02-28 17:54:00'), HH_water_level=6.928, date_time_H=Timestamp('2020-02-28 05:36:00'), H_water_level=6.877000000000001, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-02-28 12:24:00'), LL_water_level=5.412000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-02-29 06:12:00'), HH_water_level=7.021, date_time_H=Timestamp('2020-02-29 18:24:00'), H_water_level=6.942, date_time_L=Timestamp('2020-02-29 12:24:00'), L_water_level=5.481, date_time_LL=Timestamp('2020-02-29 00:18:00'), LL_water_level=5.381)
# Cumberland_County(date_time_HH=Timestamp('2020-03-01 07:06:00'), HH_water_level=7.136, date_time_H=Timestamp('2020-03-01 19:12:00'), H_water_level=7.114, date_time_L=Timestamp('2020-03-01 13:24:00'), L_water_level=5.704, date_time_LL=Timestamp('2020-03-01 00:36:00'), LL_water_level=5.527)
# Cumberland_County(date_time_HH=Timestamp('2020-03-02 07:24:00'), HH_water_level=7.505, date_time_H=Timestamp('2020-03-02 20:06:00'), H_water_level=7.1610000000000005, date_time_L=Timestamp('2020-03-02 14:18:00'), L_water_level=5.961, date_time_LL=Timestamp('2020-03-02 01:06:00'), LL_water_level=5.755)
# Cumberland_County(date_time_HH=Timestamp('2020-03-03 08:30:00'), HH_water_level=7.358, date_time_H=Timestamp('2020-03-03 21:00:00'), H_water_level=7.324, date_time_L=Timestamp('2020-03-03 14:36:00'), L_water_level=6.044, date_time_LL=Timestamp('2020-03-03 02:18:00'), LL_water_level=5.882999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-03-04 09:48:00'), HH_water_level=7.247999999999999, date_time_H=Timestamp('2020-03-04 22:00:00'), H_water_level=7.007999999999999, date_time_L=Timestamp('2020-03-04 03:48:00'), L_water_level=5.8629999999999995, date_time_LL=Timestamp('2020-03-04 16:12:00'), LL_water_level=5.834)
# Cumberland_County(date_time_HH=Timestamp('2020-03-05 10:48:00'), HH_water_level=7.216, date_time_H=Timestamp('2020-03-05 23:24:00'), H_water_level=7.148, date_time_L=Timestamp('2020-03-05 16:42:00'), L_water_level=5.705, date_time_LL=Timestamp('2020-03-05 04:36:00'), LL_water_level=5.59)
# Cumberland_County(date_time_HH=Timestamp('2020-03-06 12:06:00'), HH_water_level=7.617000000000001, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-03-06 18:36:00'), L_water_level=5.837000000000001, date_time_LL=Timestamp('2020-03-06 05:36:00'), LL_water_level=5.6579999999999995)
# Cumberland_County(date_time_HH=Timestamp('2020-03-07 12:06:00'), HH_water_level=7.72, date_time_H=Timestamp('2020-03-07 00:30:00'), H_water_level=7.322, date_time_L=Timestamp('2020-03-07 06:18:00'), L_water_level=6.017, date_time_LL=Timestamp('2020-03-07 19:30:00'), LL_water_level=5.687)
# Cumberland_County(date_time_HH=Timestamp('2020-03-08 13:42:00'), HH_water_level=7.93, date_time_H=Timestamp('2020-03-08 01:42:00'), H_water_level=7.625, date_time_L=Timestamp('2020-03-08 07:48:00'), L_water_level=5.862, date_time_LL=Timestamp('2020-03-08 20:42:00'), LL_water_level=5.749)
# Cumberland_County(date_time_HH=Timestamp('2020-03-09 14:36:00'), HH_water_level=7.6129999999999995, date_time_H=Timestamp('2020-03-09 02:00:00'), H_water_level=7.6160000000000005, date_time_L=Timestamp('2020-03-09 08:54:00'), L_water_level=5.495, date_time_LL=Timestamp('2020-03-09 21:30:00'), LL_water_level=5.438)
# Cumberland_County(date_time_HH=Timestamp('2020-03-10 15:30:00'), HH_water_level=7.605, date_time_H=Timestamp('2020-03-10 03:00:00'), H_water_level=7.481, date_time_L=Timestamp('2020-03-10 22:12:00'), L_water_level=5.45, date_time_LL=Timestamp('2020-03-10 09:42:00'), LL_water_level=5.377000000000001)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-03-11 16:18:00'), H_water_level=7.697, date_time_L=Timestamp('2020-03-11 23:00:00'), L_water_level=5.57, date_time_LL=Timestamp('2020-03-11 10:36:00'), LL_water_level=5.388)
# Cumberland_County(date_time_HH=Timestamp('2020-03-12 04:36:00'), HH_water_level=7.767, date_time_H=Timestamp('2020-03-12 17:00:00'), H_water_level=7.726, date_time_L=Timestamp('2020-03-12 23:36:00'), L_water_level=5.73, date_time_LL=Timestamp('2020-03-12 11:24:00'), LL_water_level=5.636)
# Cumberland_County(date_time_HH=Timestamp('2020-03-13 05:30:00'), HH_water_level=7.893, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-03-13 12:12:00'), L_water_level=5.9, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-03-14 06:18:00'), H_water_level=7.614, date_time_L=Timestamp('2020-03-14 13:36:00'), L_water_level=5.568, date_time_LL=Timestamp('2020-03-14 00:36:00'), LL_water_level=5.678999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-03-15 07:24:00'), HH_water_level=7.439, date_time_H=Timestamp('2020-03-15 19:48:00'), H_water_level=7.216, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-03-15 14:12:00'), LL_water_level=5.622000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-03-16 08:06:00'), HH_water_level=7.484, date_time_H=Timestamp('2020-03-16 20:54:00'), H_water_level=7.374, date_time_L=Timestamp('2020-03-16 02:12:00'), L_water_level=5.737, date_time_LL=Timestamp('2020-03-16 14:48:00'), LL_water_level=5.832000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-03-17 09:18:00'), HH_water_level=7.626, date_time_H=Timestamp('2020-03-17 21:48:00'), H_water_level=7.352, date_time_L=Timestamp('2020-03-17 03:00:00'), L_water_level=6.109, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-03-18 10:18:00'), HH_water_level=7.3839999999999995, date_time_H=Timestamp('2020-03-18 23:18:00'), H_water_level=7.188, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-03-18 04:30:00'), LL_water_level=5.836)
# Cumberland_County(date_time_HH=Timestamp('2020-03-19 11:24:00'), HH_water_level=7.597, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-03-19 05:06:00'), L_water_level=5.937, date_time_LL=Timestamp('2020-03-19 18:12:00'), LL_water_level=5.765)
# Cumberland_County(date_time_HH=Timestamp('2020-03-20 12:06:00'), HH_water_level=7.609, date_time_H=Timestamp('2020-03-20 00:06:00'), H_water_level=7.324, date_time_L=Timestamp('2020-03-20 06:06:00'), L_water_level=5.974, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-03-21 13:12:00'), HH_water_level=7.371, date_time_H=Timestamp('2020-03-21 00:54:00'), H_water_level=7.232, date_time_L=Timestamp('2020-03-21 20:00:00'), L_water_level=5.614, date_time_LL=Timestamp('2020-03-21 07:12:00'), LL_water_level=5.664)
# Cumberland_County(date_time_HH=Timestamp('2020-03-22 14:12:00'), HH_water_level=7.47, date_time_H=Timestamp('2020-03-22 01:36:00'), H_water_level=7.279, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-03-22 20:18:00'), LL_water_level=5.976)
# Cumberland_County(date_time_HH=Timestamp('2020-03-23 14:48:00'), HH_water_level=7.747999999999999, date_time_H=Timestamp('2020-03-23 02:12:00'), H_water_level=7.561, date_time_L=Timestamp('2020-03-23 21:18:00'), L_water_level=6.071000000000001, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-03-24 15:18:00'), HH_water_level=7.53, date_time_H=Timestamp('2020-03-24 02:30:00'), H_water_level=7.486000000000001, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-03-24 09:12:00'), LL_water_level=5.763)
# Cumberland_County(date_time_HH=Timestamp('2020-03-25 16:00:00'), HH_water_level=7.817, date_time_H=Timestamp('2020-03-25 03:24:00'), H_water_level=7.553, date_time_L=Timestamp('2020-03-25 22:12:00'), L_water_level=6.216, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-03-26 03:54:00'), HH_water_level=7.746, date_time_H=Timestamp('2020-03-26 16:18:00'), H_water_level=7.69, date_time_L=Timestamp('2020-03-26 22:30:00'), L_water_level=6.1, date_time_LL=Timestamp('2020-03-26 10:36:00'), LL_water_level=6.027)
# Cumberland_County(date_time_HH=Timestamp('2020-03-27 04:12:00'), HH_water_level=7.757000000000001, date_time_H=Timestamp('2020-03-27 16:48:00'), H_water_level=7.612, date_time_L=Timestamp('2020-03-27 23:00:00'), L_water_level=5.96, date_time_LL=Timestamp('2020-03-27 11:00:00'), LL_water_level=5.925)
# Cumberland_County(date_time_HH=Timestamp('2020-03-28 04:48:00'), HH_water_level=7.726, date_time_H=Timestamp('2020-03-28 17:24:00'), H_water_level=7.5, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-03-28 23:36:00'), LL_water_level=5.962999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-03-29 05:36:00'), HH_water_level=7.647, date_time_H=Timestamp('2020-03-29 18:00:00'), H_water_level=7.507000000000001, date_time_L=Timestamp('2020-03-29 23:54:00'), L_water_level=6.165, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-03-30 06:06:00'), HH_water_level=7.773, date_time_H=Timestamp('2020-03-30 18:48:00'), H_water_level=7.459, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-03-30 12:54:00'), LL_water_level=6.068)
# Cumberland_County(date_time_HH=Timestamp('2020-03-31 07:00:00'), HH_water_level=7.6579999999999995, date_time_H=Timestamp('2020-03-31 19:24:00'), H_water_level=7.61, date_time_L=Timestamp('2020-03-31 13:18:00'), L_water_level=6.222, date_time_LL=Timestamp('2020-03-31 00:48:00'), LL_water_level=6.106)
# Cumberland_County(date_time_HH=Timestamp('2020-04-01 07:48:00'), HH_water_level=7.859, date_time_H=Timestamp('2020-04-01 20:54:00'), H_water_level=7.484, date_time_L=Timestamp('2020-04-01 01:30:00'), L_water_level=6.409, date_time_LL=Timestamp('2020-04-01 14:54:00'), LL_water_level=6.356)
# Cumberland_County(date_time_HH=Timestamp('2020-04-02 08:36:00'), HH_water_level=7.4639999999999995, date_time_H=Timestamp('2020-04-02 21:42:00'), H_water_level=7.1770000000000005, date_time_L=Timestamp('2020-04-02 03:00:00'), L_water_level=6.271, date_time_LL=Timestamp('2020-04-02 15:48:00'), LL_water_level=5.83)
# Cumberland_County(date_time_HH=Timestamp('2020-04-03 09:54:00'), HH_water_level=7.527, date_time_H=Timestamp('2020-04-03 23:12:00'), H_water_level=7.457999999999999, date_time_L=Timestamp('2020-04-03 03:54:00'), L_water_level=6.004, date_time_LL=Timestamp('2020-04-03 16:54:00'), LL_water_level=5.856)
# Cumberland_County(date_time_HH=Timestamp('2020-04-04 11:30:00'), HH_water_level=8.036, date_time_H=Timestamp('2020-04-04 23:54:00'), H_water_level=7.867999999999999, date_time_L=Timestamp('2020-04-04 18:00:00'), L_water_level=6.312, date_time_LL=Timestamp('2020-04-04 04:54:00'), LL_water_level=6.189)
# Cumberland_County(date_time_HH=Timestamp('2020-04-05 12:06:00'), HH_water_level=7.921, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-04-05 06:24:00'), L_water_level=6.099, date_time_LL=Timestamp('2020-04-05 19:12:00'), LL_water_level=5.864)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-04-06 00:48:00'), H_water_level=7.71, date_time_L=Timestamp('2020-04-06 07:30:00'), L_water_level=5.7139999999999995, date_time_LL=Timestamp('2020-04-06 19:54:00'), LL_water_level=5.635)
# Cumberland_County(date_time_HH=Timestamp('2020-04-07 01:36:00'), HH_water_level=7.792999999999999, date_time_H=Timestamp('2020-04-07 14:06:00'), H_water_level=7.777, date_time_L=Timestamp('2020-04-07 20:48:00'), L_water_level=5.691, date_time_LL=Timestamp('2020-04-07 08:36:00'), LL_water_level=5.63)
# Cumberland_County(date_time_HH=Timestamp('2020-04-08 02:30:00'), HH_water_level=7.905, date_time_H=Timestamp('2020-04-08 15:06:00'), H_water_level=7.812, date_time_L=Timestamp('2020-04-08 21:42:00'), L_water_level=5.692, date_time_LL=Timestamp('2020-04-08 09:30:00'), LL_water_level=5.665)
# Cumberland_County(date_time_HH=Timestamp('2020-04-09 03:18:00'), HH_water_level=8.064, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-04-09 10:12:00'), L_water_level=5.824, date_time_LL=Timestamp('2020-04-09 22:48:00'), LL_water_level=5.4639999999999995)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-04-10 04:06:00'), H_water_level=7.737, date_time_L=Timestamp('2020-04-10 11:12:00'), L_water_level=5.441, date_time_LL=Timestamp('2020-04-10 23:42:00'), LL_water_level=4.976)
# Cumberland_County(date_time_HH=Timestamp('2020-04-11 05:18:00'), HH_water_level=7.274, date_time_H=Timestamp('2020-04-11 17:48:00'), H_water_level=7.22, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-04-11 12:12:00'), LL_water_level=5.245)
# Cumberland_County(date_time_HH=Timestamp('2020-04-12 05:54:00'), HH_water_level=7.725, date_time_H=Timestamp('2020-04-12 18:24:00'), H_water_level=7.45, date_time_L=Timestamp('2020-04-12 00:00:00'), L_water_level=5.407, date_time_LL=Timestamp('2020-04-12 12:48:00'), LL_water_level=5.635)
# Cumberland_County(date_time_HH=Timestamp('2020-04-13 06:48:00'), HH_water_level=7.744, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-04-13 13:30:00'), L_water_level=6.2, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-04-14 07:36:00'), H_water_level=7.287000000000001, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-04-14 02:18:00'), LL_water_level=5.65)
# Cumberland_County(date_time_HH=Timestamp('2020-04-15 08:12:00'), HH_water_level=7.269, date_time_H=Timestamp('2020-04-15 21:00:00'), H_water_level=7.221, date_time_L=Timestamp('2020-04-15 02:48:00'), L_water_level=5.794, date_time_LL=Timestamp('2020-04-15 15:06:00'), LL_water_level=5.812)
# Cumberland_County(date_time_HH=Timestamp('2020-04-16 09:36:00'), HH_water_level=7.534, date_time_H=Timestamp('2020-04-16 22:18:00'), H_water_level=6.979, date_time_L=Timestamp('2020-04-16 03:30:00'), L_water_level=5.8839999999999995, date_time_LL=Timestamp('2020-04-16 16:48:00'), LL_water_level=5.572)
# Cumberland_County(date_time_HH=Timestamp('2020-04-17 10:48:00'), HH_water_level=7.462999999999999, date_time_H=Timestamp('2020-04-17 23:12:00'), H_water_level=7.2989999999999995, date_time_L=Timestamp('2020-04-17 04:42:00'), L_water_level=5.638, date_time_LL=Timestamp('2020-04-17 17:36:00'), LL_water_level=5.647)
# Cumberland_County(date_time_HH=Timestamp('2020-04-18 12:00:00'), HH_water_level=7.385, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-04-18 05:42:00'), L_water_level=5.858, date_time_LL=Timestamp('2020-04-18 19:00:00'), LL_water_level=5.568)
# Cumberland_County(date_time_HH=Timestamp('2020-04-19 12:24:00'), HH_water_level=7.585, date_time_H=Timestamp('2020-04-19 01:12:00'), H_water_level=7.247999999999999, date_time_L=Timestamp('2020-04-19 06:42:00'), L_water_level=6.025, date_time_LL=Timestamp('2020-04-19 19:06:00'), LL_water_level=5.694)
# Cumberland_County(date_time_HH=Timestamp('2020-04-20 13:12:00'), HH_water_level=7.629, date_time_H=Timestamp('2020-04-20 01:00:00'), H_water_level=7.46, date_time_L=Timestamp('2020-04-20 07:18:00'), L_water_level=5.83, date_time_LL=Timestamp('2020-04-20 19:42:00'), LL_water_level=5.872999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-04-21 01:36:00'), HH_water_level=7.72, date_time_H=Timestamp('2020-04-21 13:54:00'), H_water_level=7.69, date_time_L=Timestamp('2020-04-21 08:12:00'), L_water_level=5.999, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-04-22 14:30:00'), HH_water_level=7.367000000000001, date_time_H=Timestamp('2020-04-22 02:12:00'), H_water_level=7.235, date_time_L=Timestamp('2020-04-22 21:06:00'), L_water_level=5.56, date_time_LL=Timestamp('2020-04-22 08:30:00'), LL_water_level=5.471)
# Cumberland_County(date_time_HH=Timestamp('2020-04-23 02:48:00'), HH_water_level=7.489, date_time_H=Timestamp('2020-04-23 15:24:00'), H_water_level=7.37, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-04-23 21:18:00'), LL_water_level=5.757999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-04-24 03:24:00'), HH_water_level=7.711, date_time_H=Timestamp('2020-04-24 15:42:00'), H_water_level=7.5120000000000005, date_time_L=Timestamp('2020-04-24 10:12:00'), L_water_level=5.872999999999999, date_time_LL=Timestamp('2020-04-24 21:54:00'), LL_water_level=5.852)
# Cumberland_County(date_time_HH=Timestamp('2020-04-25 03:54:00'), HH_water_level=7.812, date_time_H=Timestamp('2020-04-25 16:12:00'), H_water_level=7.42, date_time_L=Timestamp('2020-04-25 10:54:00'), L_water_level=5.861000000000001, date_time_LL=Timestamp('2020-04-25 22:24:00'), LL_water_level=5.9079999999999995)
# Cumberland_County(date_time_HH=Timestamp('2020-04-26 04:24:00'), HH_water_level=7.78, date_time_H=Timestamp('2020-04-26 16:48:00'), H_water_level=7.521, date_time_L=Timestamp('2020-04-26 23:00:00'), L_water_level=5.973, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-04-27 05:12:00'), HH_water_level=7.805, date_time_H=Timestamp('2020-04-27 17:30:00'), H_water_level=7.274, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-04-27 11:54:00'), LL_water_level=5.952999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-04-28 06:00:00'), HH_water_level=7.542999999999999, date_time_H=Timestamp('2020-04-28 18:30:00'), H_water_level=7.462000000000001, date_time_L=Timestamp('2020-04-28 12:36:00'), L_water_level=5.854, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-04-29 06:36:00'), HH_water_level=7.699, date_time_H=Timestamp('2020-04-29 19:18:00'), H_water_level=7.457999999999999, date_time_L=Timestamp('2020-04-29 13:24:00'), L_water_level=6.0329999999999995, date_time_LL=Timestamp('2020-04-29 00:30:00'), LL_water_level=6.018)
# Cumberland_County(date_time_HH=Timestamp('2020-04-30 20:30:00'), HH_water_level=7.867999999999999, date_time_H=Timestamp('2020-04-30 07:24:00'), H_water_level=7.7989999999999995, date_time_L=Timestamp('2020-04-30 14:06:00'), L_water_level=6.329, date_time_LL=Timestamp('2020-04-30 01:12:00'), LL_water_level=6.144)
# Cumberland_County(date_time_HH=Timestamp('2020-05-01 08:42:00'), HH_water_level=7.72, date_time_H=Timestamp('2020-05-01 21:24:00'), H_water_level=7.519, date_time_L=Timestamp('2020-05-01 03:18:00'), L_water_level=6.231, date_time_LL=Timestamp('2020-05-01 15:36:00'), LL_water_level=5.979)
# Cumberland_County(date_time_HH=Timestamp('2020-05-02 09:48:00'), HH_water_level=7.524, date_time_H=Timestamp('2020-05-02 22:24:00'), H_water_level=7.495, date_time_L=Timestamp('2020-05-02 03:54:00'), L_water_level=5.914, date_time_LL=Timestamp('2020-05-02 16:30:00'), LL_water_level=5.692)
# Cumberland_County(date_time_HH=Timestamp('2020-05-03 10:54:00'), HH_water_level=7.694, date_time_H=Timestamp('2020-05-03 23:36:00'), H_water_level=7.597, date_time_L=Timestamp('2020-05-03 04:48:00'), L_water_level=5.726, date_time_LL=Timestamp('2020-05-03 17:42:00'), LL_water_level=5.653)
# Cumberland_County(date_time_HH=Timestamp('2020-05-04 12:06:00'), HH_water_level=7.772, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-05-04 18:42:00'), L_water_level=5.683, date_time_LL=Timestamp('2020-05-04 06:00:00'), LL_water_level=5.683)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-05-05 12:54:00'), H_water_level=7.617000000000001, date_time_L=Timestamp('2020-05-05 07:12:00'), L_water_level=5.542999999999999, date_time_LL=Timestamp('2020-05-05 19:30:00'), LL_water_level=5.511)
# Cumberland_County(date_time_HH=Timestamp('2020-05-06 01:30:00'), HH_water_level=7.8629999999999995, date_time_H=Timestamp('2020-05-06 13:48:00'), H_water_level=7.843, date_time_L=Timestamp('2020-05-06 20:30:00'), L_water_level=5.697, date_time_LL=Timestamp('2020-05-06 08:12:00'), LL_water_level=5.631)
# Cumberland_County(date_time_HH=Timestamp('2020-05-07 02:18:00'), HH_water_level=8.03, date_time_H=Timestamp('2020-05-07 14:42:00'), H_water_level=7.6160000000000005, date_time_L=Timestamp('2020-05-07 09:24:00'), L_water_level=5.709, date_time_LL=Timestamp('2020-05-07 21:06:00'), LL_water_level=5.537000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-05-08 03:06:00'), HH_water_level=8.026, date_time_H=Timestamp('2020-05-08 15:42:00'), H_water_level=7.624, date_time_L=Timestamp('2020-05-08 21:54:00'), L_water_level=5.678, date_time_LL=Timestamp('2020-05-08 10:12:00'), LL_water_level=5.582000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-05-09 03:42:00'), HH_water_level=7.893, date_time_H=Timestamp('2020-05-09 16:42:00'), H_water_level=7.242999999999999, date_time_L=Timestamp('2020-05-09 23:18:00'), L_water_level=5.251, date_time_LL=Timestamp('2020-05-09 11:00:00'), LL_water_level=5.164)
# Cumberland_County(date_time_HH=Timestamp('2020-05-10 04:48:00'), HH_water_level=7.292000000000001, date_time_H=Timestamp('2020-05-10 17:30:00'), H_water_level=7.03, date_time_L=Timestamp('2020-05-10 23:48:00'), L_water_level=5.234, date_time_LL=Timestamp('2020-05-10 12:00:00'), LL_water_level=5.14)
# Cumberland_County(date_time_HH=Timestamp('2020-05-11 05:48:00'), HH_water_level=7.462999999999999, date_time_H=Timestamp('2020-05-11 18:12:00'), H_water_level=7.1160000000000005, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-05-11 12:42:00'), LL_water_level=5.315)
# Cumberland_County(date_time_HH=Timestamp('2020-05-12 06:30:00'), HH_water_level=7.434, date_time_H=Timestamp('2020-05-12 19:00:00'), H_water_level=7.127999999999999, date_time_L=Timestamp('2020-05-12 00:30:00'), L_water_level=5.452999999999999, date_time_LL=Timestamp('2020-05-12 13:36:00'), LL_water_level=5.497999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-05-13 07:12:00'), HH_water_level=7.495, date_time_H=Timestamp('2020-05-13 19:54:00'), H_water_level=7.273, date_time_L=Timestamp('2020-05-13 01:06:00'), L_water_level=5.577000000000001, date_time_LL=Timestamp('2020-05-13 14:06:00'), LL_water_level=5.546)
# Cumberland_County(date_time_HH=Timestamp('2020-05-14 08:12:00'), HH_water_level=7.346, date_time_H=Timestamp('2020-05-14 20:54:00'), H_water_level=7.196000000000001, date_time_L=Timestamp('2020-05-14 02:18:00'), L_water_level=5.696000000000001, date_time_LL=Timestamp('2020-05-14 15:00:00'), LL_water_level=5.564)
# Cumberland_County(date_time_HH=Timestamp('2020-05-15 09:12:00'), HH_water_level=7.374, date_time_H=Timestamp('2020-05-15 21:42:00'), H_water_level=7.223, date_time_L=Timestamp('2020-05-15 03:06:00'), L_water_level=5.773, date_time_LL=Timestamp('2020-05-15 16:00:00'), LL_water_level=5.591)
# Cumberland_County(date_time_HH=Timestamp('2020-05-16 10:18:00'), HH_water_level=7.2379999999999995, date_time_H=Timestamp('2020-05-16 22:54:00'), H_water_level=7.332999999999999, date_time_L=Timestamp('2020-05-16 04:12:00'), L_water_level=5.763, date_time_LL=Timestamp('2020-05-16 16:48:00'), LL_water_level=5.551)
# Cumberland_County(date_time_HH=Timestamp('2020-05-17 23:30:00'), HH_water_level=7.532, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-05-17 05:00:00'), L_water_level=5.853, date_time_LL=Timestamp('2020-05-17 17:18:00'), LL_water_level=5.942)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-05-18 11:48:00'), H_water_level=7.445, date_time_L=Timestamp('2020-05-18 06:06:00'), L_water_level=5.995, date_time_LL=Timestamp('2020-05-18 18:18:00'), LL_water_level=5.896)
# Cumberland_County(date_time_HH=Timestamp('2020-05-19 12:48:00'), HH_water_level=7.564, date_time_H=Timestamp('2020-05-19 00:12:00'), H_water_level=7.539, date_time_L=Timestamp('2020-05-19 06:42:00'), L_water_level=6.041, date_time_LL=Timestamp('2020-05-19 18:54:00'), LL_water_level=6.249)
# Cumberland_County(date_time_HH=Timestamp('2020-05-20 01:12:00'), HH_water_level=7.825, date_time_H=Timestamp('2020-05-20 13:24:00'), H_water_level=7.567, date_time_L=Timestamp('2020-05-20 07:48:00'), L_water_level=6.2860000000000005, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-05-21 01:36:00'), HH_water_level=7.692, date_time_H=Timestamp('2020-05-21 14:06:00'), H_water_level=7.407, date_time_L=Timestamp('2020-05-21 20:24:00'), L_water_level=5.82, date_time_LL=Timestamp('2020-05-21 08:30:00'), LL_water_level=5.9079999999999995)
# Cumberland_County(date_time_HH=Timestamp('2020-05-22 02:12:00'), HH_water_level=7.609, date_time_H=Timestamp('2020-05-22 14:48:00'), H_water_level=7.329, date_time_L=Timestamp('2020-05-22 21:00:00'), L_water_level=5.716, date_time_LL=Timestamp('2020-05-22 09:06:00'), LL_water_level=5.65)
# Cumberland_County(date_time_HH=Timestamp('2020-05-23 02:48:00'), HH_water_level=7.638, date_time_H=Timestamp('2020-05-23 15:24:00'), H_water_level=7.29, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-05-23 21:30:00'), LL_water_level=5.6610000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-05-24 03:24:00'), HH_water_level=7.791, date_time_H=Timestamp('2020-05-24 15:54:00'), H_water_level=7.577999999999999, date_time_L=Timestamp('2020-05-24 22:06:00'), L_water_level=5.9879999999999995, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-05-25 04:00:00'), HH_water_level=7.851, date_time_H=Timestamp('2020-05-25 16:36:00'), H_water_level=7.438, date_time_L=Timestamp('2020-05-25 22:48:00'), L_water_level=5.796, date_time_LL=Timestamp('2020-05-25 11:06:00'), LL_water_level=5.835)
# Cumberland_County(date_time_HH=Timestamp('2020-05-26 04:42:00'), HH_water_level=7.771, date_time_H=Timestamp('2020-05-26 17:12:00'), H_water_level=7.367999999999999, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-05-26 23:24:00'), LL_water_level=5.772)
# Cumberland_County(date_time_HH=Timestamp('2020-05-27 05:36:00'), HH_water_level=7.776, date_time_H=Timestamp('2020-05-27 18:06:00'), H_water_level=7.3420000000000005, date_time_L=Timestamp('2020-05-27 12:36:00'), L_water_level=5.782, date_time_LL=NaT, LL_water_level=nan)
# Cumberland_County(date_time_HH=Timestamp('2020-05-28 06:18:00'), HH_water_level=7.721, date_time_H=Timestamp('2020-05-28 19:06:00'), H_water_level=7.45, date_time_L=Timestamp('2020-05-28 13:18:00'), L_water_level=5.865, date_time_LL=Timestamp('2020-05-28 00:18:00'), LL_water_level=5.8020000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-05-29 07:12:00'), HH_water_level=7.699, date_time_H=Timestamp('2020-05-29 20:06:00'), H_water_level=7.412999999999999, date_time_L=Timestamp('2020-05-29 01:12:00'), L_water_level=5.936, date_time_LL=Timestamp('2020-05-29 14:24:00'), LL_water_level=5.766)
# Cumberland_County(date_time_HH=Timestamp('2020-05-30 08:12:00'), HH_water_level=7.621, date_time_H=Timestamp('2020-05-30 21:18:00'), H_water_level=7.446000000000001, date_time_L=Timestamp('2020-05-30 02:24:00'), L_water_level=5.835, date_time_LL=Timestamp('2020-05-30 15:18:00'), LL_water_level=5.625)
# Cumberland_County(date_time_HH=Timestamp('2020-05-31 09:12:00'), HH_water_level=7.51, date_time_H=Timestamp('2020-05-31 22:06:00'), H_water_level=7.495, date_time_L=Timestamp('2020-05-31 03:30:00'), L_water_level=5.785, date_time_LL=Timestamp('2020-05-31 16:00:00'), LL_water_level=5.601)
# Cumberland_County(date_time_HH=Timestamp('2020-06-01 23:06:00'), HH_water_level=7.67, date_time_H=Timestamp('2020-06-01 10:24:00'), H_water_level=7.608, date_time_L=Timestamp('2020-06-01 04:30:00'), L_water_level=5.691, date_time_LL=Timestamp('2020-06-01 17:12:00'), LL_water_level=5.671)
# Cumberland_County(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2020-06-02 11:36:00'), H_water_level=7.513, date_time_L=Timestamp('2020-06-02 18:12:00'), L_water_level=5.593999999999999, date_time_LL=Timestamp('2020-06-02 05:48:00'), LL_water_level=5.581)
# Cumberland_County(date_time_HH=Timestamp('2020-06-03 00:12:00'), HH_water_level=7.792999999999999, date_time_H=Timestamp('2020-06-03 12:24:00'), H_water_level=7.605, date_time_L=Timestamp('2020-06-03 07:00:00'), L_water_level=5.702999999999999, date_time_LL=Timestamp('2020-06-03 19:06:00'), LL_water_level=5.649)
# Cumberland_County(date_time_HH=Timestamp('2020-06-04 01:06:00'), HH_water_level=7.941, date_time_H=Timestamp('2020-06-04 13:24:00'), H_water_level=7.632999999999999, date_time_L=Timestamp('2020-06-04 07:54:00'), L_water_level=5.6579999999999995, date_time_LL=Timestamp('2020-06-04 19:54:00'), LL_water_level=5.6160000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-06-05 01:54:00'), HH_water_level=8.002, date_time_H=Timestamp('2020-06-05 14:24:00'), H_water_level=7.602, date_time_L=Timestamp('2020-06-05 09:00:00'), L_water_level=5.64, date_time_LL=Timestamp('2020-06-05 20:48:00'), LL_water_level=5.627000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-06-06 02:42:00'), HH_water_level=7.962999999999999, date_time_H=Timestamp('2020-06-06 15:18:00'), H_water_level=7.518, date_time_L=Timestamp('2020-06-06 21:36:00'), L_water_level=5.619, date_time_LL=Timestamp('2020-06-06 09:54:00'), LL_water_level=5.5920000000000005)
# Cumberland_County(date_time_HH=Timestamp('2020-06-07 03:30:00'), HH_water_level=7.945, date_time_H=Timestamp('2020-06-07 16:00:00'), H_water_level=7.417999999999999, date_time_L=Timestamp('2020-06-07 10:42:00'), L_water_level=5.604, date_time_LL=Timestamp('2020-06-07 22:24:00'), LL_water_level=5.593999999999999)
# Cumberland_County(date_time_HH=Timestamp('2020-06-08 04:24:00'), HH_water_level=7.907, date_time_H=Timestamp('2020-06-08 16:54:00'), H_water_level=7.42, date_time_L=Timestamp('2020-06-08 23:06:00'), L_water_level=5.707999999999999, date_time_LL=Timestamp('2020-06-08 11:30:00'), LL_water_level=5.667000000000001)
# Cumberland_County(date_time_HH=Timestamp('2020-06-09 05:00:00'), HH_water_level=7.803, date_time_H=Timestamp('2020-06-09 17:42:00'), H_water_level=7.41, date_time_L=Timestamp('2020-06-09 23:54:00'), L_water_level=5.854, date_time_LL=Timestamp('2020-06-09 12:12:00'), LL_water_level=5.647)
# Cumberland_County(date_time_HH=Timestamp('2020-06-10 05:54:00'), HH_water_level=7.7410000000000005, date_time_H=Timestamp('2020-06-10 18:42:00'), H_water_level=7.492000000000001, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2020-06-10 12:48:00'), LL_water_level=5.761)
# Cumberland_County(date_time_HH=Timestamp('2020-06-11 06:48:00'), HH_water_level=7.697, date_time_H=Timestamp('2020-06-11 19:18:00'), H_water_level=7.297000000000001, date_time_L=Timestamp('2020-06-11 00:42:00'), L_water_level=6.058, date_time_LL=Timestamp('2020-06-11 13:48:00'), LL_water_level=5.82)
# Cumberland_County(date_time_HH=Timestamp('2020-06-12 07:36:00'), HH_water_level=7.5, date_time_H=Timestamp('2020-06-12 20:18:00'), H_water_level=7.312, date_time_L=Timestamp('2020-06-12 01:36:00'), L_water_level=5.855, date_time_LL=Timestamp('2020-06-12 14:30:00'), LL_water_level=5.644)
# Cumberland_County(date_time_HH=Timestamp('2020-06-13 20:54:00'), HH_water_level=7.4270000000000005, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-06-13 02:30:00'), L_water_level=5.922999999999999, date_time_LL=Timestamp('2020-06-13 14:54:00'), LL_water_level=5.749)
# Cumberland_County(date_time_HH=Timestamp('2020-06-14 21:42:00'), HH_water_level=7.5520000000000005, date_time_H=Timestamp('2020-06-14 09:18:00'), H_water_level=7.421, date_time_L=Timestamp('2020-06-14 03:24:00'), L_water_level=5.981, date_time_LL=Timestamp('2020-06-14 15:42:00'), LL_water_level=5.96)
# ...
# Atlantic_City(date_time_HH=Timestamp('2020-12-24 08:12:00'), HH_water_level=2.864, date_time_H=Timestamp('2020-12-24 20:12:00'), H_water_level=2.748, date_time_L=Timestamp('2020-12-24 14:24:00'), L_water_level=2.032, date_time_LL=Timestamp('2020-12-24 01:18:00'), LL_water_level=1.75)
# Atlantic_City(date_time_HH=Timestamp('2020-12-25 07:48:00'), HH_water_level=3.0989999999999998, date_time_H=Timestamp('2020-12-25 21:00:00'), H_water_level=2.592, date_time_L=Timestamp('2020-12-25 15:12:00'), L_water_level=2.141, date_time_LL=Timestamp('2020-12-25 02:06:00'), LL_water_level=2.114)
# Atlantic_City(date_time_HH=Timestamp('2020-12-26 09:30:00'), HH_water_level=2.585, date_time_H=Timestamp('2020-12-26 22:00:00'), H_water_level=2.332, date_time_L=Timestamp('2020-12-26 03:12:00'), L_water_level=1.511, date_time_LL=Timestamp('2020-12-26 15:54:00'), LL_water_level=1.406)
# Atlantic_City(date_time_HH=Timestamp('2020-12-27 10:12:00'), HH_water_level=2.7739999999999996, date_time_H=Timestamp('2020-12-27 22:42:00'), H_water_level=2.633, date_time_L=Timestamp('2020-12-27 16:42:00'), L_water_level=1.683, date_time_LL=Timestamp('2020-12-27 03:36:00'), LL_water_level=1.4409999999999998)
# Atlantic_City(date_time_HH=Timestamp('2020-12-28 11:06:00'), HH_water_level=2.985, date_time_H=Timestamp('2020-12-28 23:06:00'), H_water_level=2.608, date_time_L=Timestamp('2020-12-28 04:30:00'), L_water_level=1.7369999999999999, date_time_LL=Timestamp('2020-12-28 18:00:00'), LL_water_level=1.704)
# Atlantic_City(date_time_HH=Timestamp('2020-12-29 11:48:00'), HH_water_level=2.95, date_time_H=Timestamp('2020-12-29 23:24:00'), H_water_level=2.463, date_time_L=Timestamp('2020-12-29 05:12:00'), L_water_level=1.642, date_time_LL=Timestamp('2020-12-29 18:12:00'), LL_water_level=1.482)
# Atlantic_City(date_time_HH=Timestamp('2020-12-30 12:12:00'), HH_water_level=2.9560000000000004, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2020-12-30 18:54:00'), L_water_level=1.499, date_time_LL=Timestamp('2020-12-30 05:48:00'), LL_water_level=1.494)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2020-12-31 13:12:00'), HH_water_level=2.839, date_time_H=Timestamp('2020-12-31 00:30:00'), H_water_level=2.492, date_time_L=Timestamp('2020-12-31 06:30:00'), L_water_level=1.4780000000000002, date_time_LL=Timestamp('2020-12-31 19:24:00'), LL_water_level=1.367)
# Atlantic_City(date_time_HH=Timestamp('2021-01-01 13:48:00'), HH_water_level=3.068, date_time_H=Timestamp('2021-01-01 01:54:00'), H_water_level=2.505, date_time_L=Timestamp('2021-01-01 20:00:00'), L_water_level=1.641, date_time_LL=Timestamp('2021-01-01 07:06:00'), LL_water_level=1.5019999999999998)
# Atlantic_City(date_time_HH=Timestamp('2021-01-02 14:00:00'), HH_water_level=3.0610000000000004, date_time_H=Timestamp('2021-01-02 02:24:00'), H_water_level=2.839, date_time_L=Timestamp('2021-01-02 07:24:00'), L_water_level=1.805, date_time_LL=Timestamp('2021-01-02 20:18:00'), LL_water_level=1.555)
# Atlantic_City(date_time_HH=Timestamp('2021-01-03 15:48:00'), HH_water_level=3.17, date_time_H=Timestamp('2021-01-03 03:18:00'), H_water_level=2.542, date_time_L=Timestamp('2021-01-03 22:06:00'), L_water_level=2.005, date_time_LL=Timestamp('2021-01-03 08:48:00'), LL_water_level=1.661)
# Atlantic_City(date_time_HH=Timestamp('2021-01-04 16:00:00'), HH_water_level=3.279, date_time_H=Timestamp('2021-01-04 04:12:00'), H_water_level=3.173, date_time_L=Timestamp('2021-01-04 10:00:00'), L_water_level=2.075, date_time_LL=Timestamp('2021-01-04 22:48:00'), LL_water_level=1.972)
# Atlantic_City(date_time_HH=Timestamp('2021-01-05 16:54:00'), HH_water_level=3.2560000000000002, date_time_H=Timestamp('2021-01-05 04:48:00'), H_water_level=3.1310000000000002, date_time_L=Timestamp('2021-01-05 10:30:00'), L_water_level=2.046, date_time_LL=Timestamp('2021-01-05 23:36:00'), LL_water_level=2.03)
# Atlantic_City(date_time_HH=Timestamp('2021-01-06 05:48:00'), HH_water_level=3.259, date_time_H=Timestamp('2021-01-06 17:48:00'), H_water_level=3.156, date_time_L=Timestamp('2021-01-06 11:42:00'), L_water_level=2.135, date_time_LL=NaT, LL_water_level=nan)
# Atlantic_City(date_time_HH=Timestamp('2021-01-07 06:36:00'), HH_water_level=3.1839999999999997, date_time_H=Timestamp('2021-01-07 18:42:00'), H_water_level=3.002, date_time_L=Timestamp('2021-01-07 12:36:00'), L_water_level=2.061, date_time_LL=Timestamp('2021-01-07 00:24:00'), LL_water_level=1.9069999999999998)
# Atlantic_City(date_time_HH=Timestamp('2021-01-08 08:00:00'), HH_water_level=3.125, date_time_H=Timestamp('2021-01-08 19:42:00'), H_water_level=2.91, date_time_L=Timestamp('2021-01-08 13:24:00'), L_water_level=1.921, date_time_LL=Timestamp('2021-01-08 01:18:00'), LL_water_level=1.807)
# Atlantic_City(date_time_HH=Timestamp('2021-01-09 08:36:00'), HH_water_level=3.2889999999999997, date_time_H=Timestamp('2021-01-09 21:30:00'), H_water_level=2.9789999999999996, date_time_L=Timestamp('2021-01-09 15:24:00'), L_water_level=1.955, date_time_LL=Timestamp('2021-01-09 02:18:00'), LL_water_level=1.76)
# Atlantic_City(date_time_HH=Timestamp('2021-01-10 09:36:00'), HH_water_level=3.272, date_time_H=Timestamp('2021-01-10 22:12:00'), H_water_level=2.923, date_time_L=Timestamp('2021-01-10 16:06:00'), L_water_level=1.689, date_time_LL=Timestamp('2021-01-10 03:18:00'), LL_water_level=1.7619999999999998)
# Atlantic_City(date_time_HH=Timestamp('2021-01-11 10:54:00'), HH_water_level=3.2089999999999996, date_time_H=Timestamp('2021-01-11 23:12:00'), H_water_level=2.782, date_time_L=Timestamp('2021-01-11 17:12:00'), L_water_level=1.531, date_time_LL=Timestamp('2021-01-11 04:12:00'), LL_water_level=1.6569999999999998)
# Atlantic_City(date_time_HH=Timestamp('2021-01-12 11:36:00'), HH_water_level=3.196, date_time_H=Timestamp('2021-01-12 23:48:00'), H_water_level=2.8089999999999997, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2021-01-12 05:06:00'), LL_water_level=1.528)
# Atlantic_City(date_time_HH=Timestamp('2021-01-13 12:24:00'), HH_water_level=3.3339999999999996, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2021-01-13 05:48:00'), L_water_level=1.4809999999999999, date_time_LL=Timestamp('2021-01-13 18:48:00'), LL_water_level=1.501)
# Atlantic_City(date_time_HH=Timestamp('2021-01-14 13:00:00'), HH_water_level=3.38, date_time_H=Timestamp('2021-01-14 00:42:00'), H_water_level=2.8560000000000003, date_time_L=Timestamp('2021-01-14 06:30:00'), L_water_level=1.581, date_time_LL=Timestamp('2021-01-14 19:24:00'), LL_water_level=1.5859999999999999)
# Atlantic_City(date_time_HH=Timestamp('2021-01-15 13:54:00'), HH_water_level=3.403, date_time_H=Timestamp('2021-01-15 01:36:00'), H_water_level=2.923, date_time_L=Timestamp('2021-01-15 07:30:00'), L_water_level=1.722, date_time_LL=Timestamp('2021-01-15 20:06:00'), LL_water_level=1.8)
# Atlantic_City(date_time_HH=Timestamp('2021-01-16 14:30:00'), HH_water_level=3.452, date_time_H=Timestamp('2021-01-16 02:18:00'), H_water_level=3.095, date_time_L=Timestamp('2021-01-16 08:00:00'), L_water_level=1.9369999999999998, date_time_LL=NaT, LL_water_level=nan)
# Atlantic_City(date_time_HH=Timestamp('2021-01-17 14:54:00'), HH_water_level=2.7089999999999996, date_time_H=Timestamp('2021-01-17 03:06:00'), H_water_level=2.846, date_time_L=NaT, L_water_level=nan, date_time_LL=Timestamp('2021-01-17 09:42:00'), LL_water_level=1.625)
# Atlantic_City(date_time_HH=Timestamp('2021-01-18 16:24:00'), HH_water_level=2.5980000000000003, date_time_H=Timestamp('2021-01-18 04:06:00'), H_water_level=2.471, date_time_L=Timestamp('2021-01-18 10:24:00'), L_water_level=1.3940000000000001, date_time_LL=Timestamp('2021-01-18 22:36:00'), LL_water_level=1.489)
# Atlantic_City(date_time_HH=NaT, HH_water_level=nan, date_time_H=Timestamp('2021-01-19 16:42:00'), H_water_level=2.553, date_time_L=Timestamp('2021-01-19 10:48:00'), L_water_level=1.578, date_time_LL=Timestamp('2021-01-19 23:18:00'), LL_water_level=1.5630000000000002)
# Atlantic_City(date_time_HH=Timestamp('2021-01-20 05:36:00'), HH_water_level=2.555, date_time_H=Timestamp('2021-01-20 17:48:00'), H_water_level=2.555, date_time_L=Timestamp('2021-01-20 11:24:00'), L_water_level=1.8719999999999999, date_time_LL=NaT, LL_water_level=nan)
# Atlantic_City(date_time_HH=Timestamp('2021-01-21 06:06:00'), HH_water_level=2.701, date_time_H=Timestamp('2021-01-21 18:18:00'), H_water_level=2.609, date_time_L=Timestamp('2021-01-21 11:48:00'), L_water_level=2.0709999999999997, date_time_LL=Timestamp('2021-01-21 00:06:00'), LL_water_level=1.756)
# Atlantic_City(date_time_HH=Timestamp('2021-01-22 07:06:00'), HH_water_level=2.795, date_time_H=Timestamp('2021-01-22 19:36:00'), H_water_level=2.521, date_time_L=Timestamp('2021-01-22 13:48:00'), L_water_level=1.999, date_time_LL=Timestamp('2021-01-22 00:36:00'), LL_water_level=1.91)
# Atlantic_City(date_time_HH=Timestamp('2021-01-23 08:06:00'), HH_water_level=2.7460000000000004, date_time_H=Timestamp('2021-01-23 20:24:00'), H_water_level=2.4330000000000003, date_time_L=Timestamp('2021-01-23 14:54:00'), L_water_level=1.814, date_time_LL=Timestamp('2021-01-23 01:42:00'), LL_water_level=1.794)
# Atlantic_City(date_time_HH=Timestamp('2021-01-24 08:30:00'), HH_water_level=2.614, date_time_H=Timestamp('2021-01-24 21:42:00'), H_water_level=2.21, date_time_L=Timestamp('2021-01-24 02:24:00'), L_water_level=1.641, date_time_LL=Timestamp('2021-01-24 15:42:00'), LL_water_level=1.5719999999999998)
# Atlantic_City(date_time_HH=Timestamp('2021-01-25 09:36:00'), HH_water_level=2.707, date_time_H=Timestamp('2021-01-25 22:12:00'), H_water_level=2.779, date_time_L=Timestamp('2021-01-25 15:48:00'), L_water_level=1.79, date_time_LL=Timestamp('2021-01-25 02:48:00'), LL_water_level=1.463)
# Atlantic_City(date_time_HH=Timestamp('2021-01-26 10:12:00'), HH_water_level=3.0780000000000003, date_time_H=Timestamp('2021-01-26 22:48:00'), H_water_level=2.8960000000000004, date_time_L=Timestamp('2021-01-26 16:48:00'), L_water_level=1.903, date_time_LL=Timestamp('2021-01-26 04:00:00'), LL_water_level=1.901)
# Atlantic_City(date_time_HH=Timestamp('2021-01-27 11:06:00'), HH_water_level=3.205, date_time_H=Timestamp('2021-01-27 23:48:00'), H_water_level=2.883, date_time_L=Timestamp('2021-01-27 16:54:00'), L_water_level=1.9040000000000001, date_time_LL=Timestamp('2021-01-27 04:36:00'), LL_water_level=1.881)
# Atlantic_City(date_time_HH=Timestamp('2021-01-28 11:36:00'), HH_water_level=3.179, date_time_H=NaT, H_water_level=nan, date_time_L=Timestamp('2021-01-28 05:42:00'), L_water_level=1.797, date_time_LL=Timestamp('2021-01-28 18:24:00'), LL_water_level=1.742)
# Atlantic_City(date_time_HH=Timestamp('2021-01-29 12:36:00'), HH_water_level=2.992, date_time_H=Timestamp('2021-01-29 00:24:00'), H_water_level=2.7439999999999998, date_time_L=Timestamp('2021-01-29 06:48:00'), L_water_level=1.5630000000000002, date_time_LL=Timestamp('2021-01-29 19:12:00'), LL_water_level=1.359)
# Atlantic_City(date_time_HH=Timestamp('2021-01-30 13:36:00'), HH_water_level=3.343, date_time_H=Timestamp('2021-01-30 01:18:00'), H_water_level=2.7119999999999997, date_time_L=Timestamp('2021-01-30 19:54:00'), L_water_level=1.7630000000000001, date_time_LL=Timestamp('2021-01-30 06:48:00'), LL_water_level=1.607)
# Atlantic_City(date_time_HH=Timestamp('2021-01-31 14:12:00'), HH_water_level=3.1830000000000003, date_time_H=Timestamp('2021-01-31 01:48:00'), H_water_level=3.035, date_time_L=Timestamp('2021-01-31 07:36:00'), L_water_level=1.675, date_time_LL=Timestamp('2021-01-31 20:30:00'), LL_water_level=1.6440000000000001)

# %% [markdown]
# FIPS codes will be needed to query the eBird database for sightings in a given county. FIPS are numbers used to uniquely identify geographic regions, such as counties. FIPS codes are five-digit integers, with the first two digits indicating the state and the last three digits being county identifers. To acquire a list of full five-digit FIPS codes, the fcc website will be scraped using beautifulsoup. This project scope is New Jersey only, while the website contains FIPS codes for all 50 states. The New Jersey state code is 34 - so a regex ('34\d{3}\s*.*') was used to parse out five-digit numbers followed by a string containign the county name. FIPS and county codes were then extracted individually. The eBird API accepts strings in the US-{two-digit state code}-{county FIPS ID} format. So for new Jersey, we would use something like US-NJ-001. The five-digit FIPS codes and county names are manipulated into the desired format below, then saved into a dictionary with county names as keys.

# %%
# importing beautifulsoup to scrape fcc.gov for fips codes (county data)
from bs4 import BeautifulSoup
import urllib.request
import re

urlpage =  'https://transition.fcc.gov/oet/info/maps/census/fips/fips.txt'
page = urllib.request.urlopen(urlpage)
soup = BeautifulSoup(page, 'html.parser')

# get all matches for FIPS -whitespace- county name (34 is NJ state code)
matches = re.findall( r'34\d{3}\s*.*', str(soup))
# the first match is the new jersey state fips code - we only need county fips codes. omitting first match
matches = matches[1:]

counties = {}
for i in range(len(matches)):
    fips_codes = re.findall(r'34\d{3}', matches[i])
    fips_code = fips_codes[0]
    county_names = re.findall(r'\s(.*County)', matches[i])
    county_name = county_names[0]
    county_name = county_name.lstrip()
    counties[county_name] = fips_code

# county fips codes are the last 3 digits of the whole code
county_fips = {}
for key, value in counties.items():
    corrected_value = value[2:5]
    corrected_value = 'US-NJ-' + corrected_value
    corrected_key = key[:-7]
    county_fips[corrected_key] = corrected_value
print(county_fips)
# Out:
# {'Atlantic': 'US-NJ-001', 'Bergen': 'US-NJ-003', 'Burlington': 'US-NJ-005', 'Camden': 'US-NJ-007', 'Cape May': 'US-NJ-009', 'Cumberland': 'US-NJ-011', 'Essex': 'US-NJ-013', 'Gloucester': 'US-NJ-015', 'Hudson': 'US-NJ-017', 'Hunterdon': 'US-NJ-019', 'Mercer': 'US-NJ-021', 'Middlesex': 'US-NJ-023', 'Monmouth': 'US-NJ-025', 'Morris': 'US-NJ-027', 'Ocean': 'US-NJ-029', 'Passaic': 'US-NJ-031', 'Salem': 'US-NJ-033', 'Somerset': 'US-NJ-035', 'Sussex': 'US-NJ-037', 'Union': 'US-NJ-039', 'Warren': 'US-NJ-041'}

# %% [markdown]
# eBird query:
#
# eBird data will be acquisitioned using the eBird API. First, the 'get_taxonomy' function is used to get species codes and associated metadata for respective species. 23 species of shorebird have been selected objectively based on relative abundance in the selected geographical region. The taxonomic data will be stored in a dictionary and leveraged to request data for the selected species using the 'get_species_observations' function, which returns fields including observation date, specie observed, observation count, observatoin time, latitude, longitude, location name, location ID, and county, among several others that will not be included for this project.
#
# eBird legacy data:
#
# Note, the eBird API is only capable of retrieving data from the past 30 days. To remedy this and meet the date range objective of the project (Jan 2020 - forward), a data request was made directly on the eBird website. Access was granted to my user account, and all observation data for New Jersey from Jan 2020 to present. The .txt file was received via email, and was filtered using Excel Power Query for respective species. In this script, the file will be read into a pandas dataframe and merged with the data requisitioned via the eBird API.

# %%
# !pip install ebird-api
# Out:
# Requirement already satisfied: ebird-api in /usr/local/lib/python3.7/dist-packages (3.0.6)

# %%
# import ebird API package and assign API key
from ebird.api import get_observations
from ebird.api import get_species_observations
from ebird.api import get_nearby_observations
from ebird.api import get_visits
from ebird.api import get_checklist
from ebird.api import get_taxonomy, get_taxonomy_forms, get_taxonomy_versions
from ebird.api import get_notable_observations
api_key = 'aape5hn8f10a' # api key obtained by request from eBird (personal use only - PLEASE DO NOT USE OR SHARE!)

# %%
taxonomy = get_taxonomy(api_key) # get scientific name, common name, species Code, category, taxonomic order, etc.

# extracting only the data we need for this project into a new dictionary
shorebirds = [] # list of dictionaries from taxonomy for shorebirds
for d in taxonomy:
    for key, value in d.items():
        if key == 'order':
            if d[key] == 'Charadriiformes':
                shorebirds.append(d)

common_names = []
species_codes = []
for i in range(len(shorebirds)):
    current_species = shorebirds[i]
    for key, value in current_species.items():
        if key == 'comName':
            common_names.append(current_species['comName'])
        if key == 'speciesCode':
            species_codes.append(current_species['speciesCode'])

shorebirds_dict_pre = {}
for i in range(len(common_names)):
    current_name = common_names[i]
    shorebirds_dict_pre[current_name] = species_codes[i]

# scope is predefined list of shorebirds (not gulls, terns, jaegers)
# need to decrease API request volume and tighten the scope of the project
narrowed_scope_abbv = ['killde', 'sander', 'dunlin', 'pursan', 'ameoys',
                       'bkbplo', 'greyel', 'semplo', 'lobdow', 'sposan',
                       'lesyel', 'leasan', 'margod', 'willet1', 'shbdow',
                       'wessan', 'pecsan', 'amgplo', 'solsan', 'stisan',
                       'hudgod', 'pipplo', 'uplsan']
shorebirds_dict = {}
for key, value in shorebirds_dict_pre.items():
  if value in narrowed_scope_abbv:
    shorebirds_dict[key] = value

for key, value in shorebirds_dict.items():
  print(key, value)
# Out:
# American Oystercatcher ameoys
# Black-bellied Plover bkbplo
# American Golden-Plover amgplo
# Semipalmated Plover semplo
# Piping Plover pipplo
# Killdeer killde
# Upland Sandpiper uplsan
# Hudsonian Godwit hudgod
# Marbled Godwit margod
# Stilt Sandpiper stisan
# Sanderling sander
# Dunlin dunlin
# Purple Sandpiper pursan
# Least Sandpiper leasan
# Pectoral Sandpiper pecsan
# Western Sandpiper wessan
# Short-billed Dowitcher shbdow
# Long-billed Dowitcher lobdow
# Spotted Sandpiper sposan
# Solitary Sandpiper solsan
# Greater Yellowlegs greyel
# Willet willet1
# Lesser Yellowlegs lesyel

# %%
# relevant counties are Atlantic, Monmouth, Cumberland and Cape May
# these queries pull a lot of data - so data will only be queried once from the API

relevant_county_codes = []
for key, value in county_fips.items():
    if key in 'Cumberland' or key in 'Monmouth' or key in 'Cape May' or key in 'Atlantic': 
        relevant_county_codes.append(value)

# list of shorebird species codes for query
relevant_species_codes = []
for key, value in shorebirds_dict.items():
    relevant_species_codes.append(value)

def append_sightings(start, stop, county, specie): # use this sparingly, data is expensive
  try: # ignore bad requests (404 errors)
      get_obs = get_species_observations(api_key, specie, county, back=30) 
      for i in range(len(get_obs)):
        current_dict = get_obs[i]
        if current_dict:
          current_dict['county'] = county
          records.append(current_dict)
  except:
    print('error')

records = []

i = 0 # the limit of records per query is 30, so we need to break it down into intervals of 30
j = 30

for c in range(len(relevant_county_codes)):
  current_county = relevant_county_codes[c]
  for n in range(len(relevant_species_codes)):
    current_specie = relevant_species_codes[n]
    append_sightings(i, j, current_county, current_specie)
    i += 30
    j += 30

# some checklists were empty (as they did not contain target species) - let's remove these
valid_records = []
for i in range(len(records)):
    if not records[i]:
        continue
    else:
        valid_records.append(records[i])

# %%
import pandas as pd
ebird_API_df = pd.DataFrame(valid_records)
ebird_API_df['obsDt']= pd.to_datetime(ebird_API_df['obsDt'])
ebird_API_df['date'] = [d.date() for d in ebird_API_df['obsDt']]
ebird_API_df['time'] = [d.time() for d in ebird_API_df['obsDt']]
ebird_API_df = ebird_API_df[['comName', 'locId', 'locName', 'date', 'time', 'howMany',
                             'lat', 'lng', 'subId', 'county']]
ebird_API_df['date'] = ebird_API_df['date'].astype('datetime64[ns]').dt.date
#ebird_API_df['date'] = ebird_API_df['date'].str.replace('-','/')
ebird_API_df = ebird_API_df.sort_values(by=['time'], ascending=False)
ebird_API_df.head()
# Out:
#                 comName      locId  ...      subId     county
# 298            Killdeer   L6144907  ...  S82130104  US-NJ-025
# 330              Dunlin  L10854077  ...  S81505295  US-NJ-025
# 209    Purple Sandpiper    L904314  ...  S82150845  US-NJ-009
# 40   Greater Yellowlegs  L11941376  ...  S82963960  US-NJ-001
# 305          Sanderling  L10874116  ...  S82899156  US-NJ-025
#
# [5 rows x 10 columns]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
nbdir = "/content/gdrive/My Drive/DSCI511/Colab/data/"
data_loc = '/content/gdrive/My Drive/DSCI511/Colab/data/project/legacy_data/nj_shorebird_legacy_data.csv'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
legacy_ebird_data = pd.read_csv(data_loc) 
legacy_ebird_data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6,7,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                          GLOBAL UNIQUE IDENTIFIER  ... Column1
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS854789436  ...     NaN
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS855442309  ...     NaN
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS855573613  ...     NaN
# 3  URN:CornellLabOfOrnithology:EBIRD:OBS853877493  ...     NaN
# 4  URN:CornellLabOfOrnithology:EBIRD:OBS855555158  ...     NaN
#
# [5 rows x 47 columns]

# %%
legacy_ebird_data = legacy_ebird_data[['OBSERVATION DATE', 'TIME OBSERVATIONS STARTED',
                                       'COMMON NAME', 'LOCALITY', 'LOCALITY ID',
                                       'LATITUDE', 'LONGITUDE', 'OBSERVATION COUNT',
                                       'COUNTY CODE', 'OBSERVER ID']]
legacy_ebird_data.columns = ['date', 'time', 'comName', 'locName', 'locId',
                             'lat', 'lng', 'howMany', 'county', 'subId']
legacy_ebird_data['date'] = legacy_ebird_data['date'].astype('datetime64[ns]').dt.date
legacy_ebird_data['time'] = legacy_ebird_data['time'].astype('datetime64[ns]').dt.time
legacy_ebird_data = legacy_ebird_data.sort_values(by=['date'], ascending=False)
legacy_ebird_data.head()
# Out:
#              date      time     comName  ... howMany     county       subId
# 48331  2021-01-31  08:28:00    Killdeer  ...       2  US-NJ-009  obsr155704
# 48689  2021-01-31  10:14:00  Sanderling  ...      33  US-NJ-009  obsr105983
# 48669  2021-01-31  13:24:00  Sanderling  ...       2  US-NJ-009  obsr134087
# 48660  2021-01-31  11:00:00  Sanderling  ...      30  US-NJ-009  obsr356525
# 48636  2021-01-31  13:25:00  Sanderling  ...       1  US-NJ-009  obsr838827
#
# [5 rows x 10 columns]

# %%
merged_ebird_df = pd.concat([legacy_ebird_data, ebird_API_df], ignore_index=True)
#merged_ebird_df = legacy_ebird_data.append(ebird_API_df)
print(legacy_ebird_data.size + ebird_API_df.size)
merged_ebird_df.size
# Out:
# 501960
# 501960

# %%
#merged_ebird_df['sightingId'] = merged_ebird_df.date.map(str) + merged_ebird_df.time.map(str) + merged_ebird_df.locId + merged_ebird_df.subId
merged_ebird_df = merged_ebird_df.sort_values(by=['comName'])
merged_ebird_df.size
# Out:
# 501960

# %% [markdown]
# Merging of data:

# %%
from typing import NamedTuple
test_list = []

class eBird_Tidal_Join(NamedTuple):
    sightingId: str
    tidal_station: str
    hh_time: datetime
    hh_water_level: float
    h_time: datetime
    h_water_level: float
    l_time: datetime
    l_water_level: float
    ll_time: datetime
    ll_water_level: float

list_of_sightings = []
test_list = []

for col, r in merged_ebird_df.iterrows(): # for row in the eBird dataframe
  obs_date_obj = r['date'] # get date as handle to join with tidal data
  test_dict = {} # create temp dict
  # for all items in the county tide dictionary
  for county, tides in tides_all.items(): # for each county in the tides dict
    current_county = county
    # get the current county's tides
    current_county_tides = tides
    # for all records in the county tide list
    for j in range(len(current_county_tides)):
      # get the current day's tides
      current_tide = current_county_tides[j]
      # get the date
      tide_date_str = str(current_tide[0])
      # if that date is not 'NaT'...
      if tide_date_str != 'NaT':
        # convert it to a datetime to match the eBird datetime so they can be compared
        tide_time_obj = datetime.strptime(tide_date_str, '%Y-%m-%d %H:%M:%S')
        # if the dates match...
        if str(obs_date_obj) == str(tide_time_obj.date()):
          # get all these variables
          #sID = r['sightingId']
          oDate = r['date']
          oTime = r['time']
          sName = r['comName']
          lName = r['locName']
          lID = r['locId']
          lat = r['lat']
          lng = r['lng']
          cnty = r['county']
          #test_dict['sightingID'] = sID
          test_dict['observationDate'] = oDate
          test_dict['observationTime'] = oTime
          test_dict['county'] = cnty
          test_dict['speciesName'] = sName
          test_dict['locationName'] = lName
          test_dict['locationID'] = lID
          test_dict['lat'] = lat
          test_dict['lng'] = lng
        
          hMany = 0
          try:
            howMany = r['howMany']
            test_dict['howMany'] = howMany
          except:
            test_dict['howMany'] = 1

          cnty_name = next(key for key, value in county_fips.items() if value == cnty)
          cnty_name = cnty_name.strip()
          if current_county == cnty_name:  
            test_dict['tideStationName'] = county
            test_dict['highhighTime'] = current_tide[0]
            test_dict['highhighWaterLevel'] = current_tide[1]
            test_dict['highTime'] = current_tide[2]
            test_dict['highWaterLevel'] = current_tide[3]
            test_dict['lowTime'] = current_tide[4]
            test_dict['lowWaterLevel'] = current_tide[5]
            test_dict['lowlowTime'] = current_tide[6]
            test_dict['lowlowWaterLevel'] = current_tide[7]
            
            test_list.append(test_dict)

# %%
all_data_df = pd.DataFrame(test_list)
all_data_df = all_data_df.sort_values(by=['observationDate'], ascending=False)
all_data_df.head(300)
# Out:
#       observationDate observationTime  ...          lowlowTime lowlowWaterLevel
# 18419      2021-02-28        07:10:00  ... 2021-02-28 19:54:00            0.598
# 4446       2021-02-28        10:42:00  ... 2021-02-28 07:36:00            0.582
# 9662       2021-02-28        13:31:00  ... 2021-02-28 07:36:00            0.582
# 18437      2021-02-28        08:05:00  ... 2021-02-28 19:54:00            0.598
# 31358      2021-02-28        08:09:00  ... 2021-02-28 07:36:00            0.582
# ...               ...             ...  ...                 ...              ...
# 31399      2021-01-30        13:15:00  ... 2021-01-30 07:42:00            0.842
# 27289      2021-01-30        10:06:00  ... 2021-01-30 06:48:00            1.607
# 31299      2021-01-30        13:05:00  ... 2021-01-30 07:36:00            0.895
# 27561      2021-01-30        08:56:00  ... 2021-01-30 06:48:00            1.607
# 31309      2021-01-30        07:34:00  ... 2021-01-30 07:42:00            0.842
#
# [300 rows x 18 columns]

# %%
all_data_df['observationTime'] = pd.to_datetime(all_data_df['observationTime'], format='%I:%M:%S %p', errors = 'ignore')
all_data_df.head(300)
# Out:
#       observationDate observationTime  ...          lowlowTime lowlowWaterLevel
# 18419      2021-02-28        07:10:00  ... 2021-02-28 19:54:00            0.598
# 4446       2021-02-28        10:42:00  ... 2021-02-28 07:36:00            0.582
# 9662       2021-02-28        13:31:00  ... 2021-02-28 07:36:00            0.582
# 18437      2021-02-28        08:05:00  ... 2021-02-28 19:54:00            0.598
# 31358      2021-02-28        08:09:00  ... 2021-02-28 07:36:00            0.582
# ...               ...             ...  ...                 ...              ...
# 31399      2021-01-30        13:15:00  ... 2021-01-30 07:42:00            0.842
# 27289      2021-01-30        10:06:00  ... 2021-01-30 06:48:00            1.607
# 31299      2021-01-30        13:05:00  ... 2021-01-30 07:36:00            0.895
# 27561      2021-01-30        08:56:00  ... 2021-01-30 06:48:00            1.607
# 31309      2021-01-30        07:34:00  ... 2021-01-30 07:42:00            0.842
#
# [300 rows x 18 columns]

# %%
final_df = all_data_df.copy()
final_df['highhighTime'] =  pd.to_datetime(final_df['highhighTime'], format='%H:%M:%S').dt.time
final_df['highhighTime'] = final_df['highhighTime'].apply(lambda x: x.strftime('%H:%M:%S'))
final_df['highTime'] =  pd.to_datetime(final_df['highTime'], format='%H:%M:%S').dt.time
final_df['lowTime'] =  pd.to_datetime(final_df['lowTime'], format='%H:%M:%S').dt.time
final_df['lowlowTime'] =  pd.to_datetime(final_df['lowlowTime'], format='%H:%M:%S').dt.time
final_df.head(300)
# Out:
#       observationDate observationTime  ... lowlowTime lowlowWaterLevel
# 18419      2021-02-28        07:10:00  ...   19:54:00            0.598
# 4446       2021-02-28        10:42:00  ...   07:36:00            0.582
# 9662       2021-02-28        13:31:00  ...   07:36:00            0.582
# 18437      2021-02-28        08:05:00  ...   19:54:00            0.598
# 31358      2021-02-28        08:09:00  ...   07:36:00            0.582
# ...               ...             ...  ...        ...              ...
# 31399      2021-01-30        13:15:00  ...   07:42:00            0.842
# 27289      2021-01-30        10:06:00  ...   06:48:00            1.607
# 31299      2021-01-30        13:05:00  ...   07:36:00            0.895
# 27561      2021-01-30        08:56:00  ...   06:48:00            1.607
# 31309      2021-01-30        07:34:00  ...   07:42:00            0.842
#
# [300 rows x 18 columns]

# %%
filepath = '/content/gdrive/My Drive/DSCI511/Colab/data/project/' + str(start_date) + '_' + str(end_date) + '.csv'
final_df.to_csv(filepath, date_format='%H:%M:%S', index = False)
